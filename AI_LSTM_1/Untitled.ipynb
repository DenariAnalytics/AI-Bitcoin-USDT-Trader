# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import load_data
import preprocess_data
import calculate as calc

# %%
# %%time
a = load_data.binance_data('BTC/USDT', 1, '2023-03-01T00:00:00Z')
# Out:
# Wall time: 2min 14s

# %%
data = load_data.local_data('C:/Users/tempf/Desktop/algo_trader/data/BTC-USDT_binance.csv',output_dataframe=True)
data
# Out:
#           close  close_pct_change     5_min_EMA    15_min_EMA    25_min_EMA  \
# 0      23170.13         -0.000342  23181.324127  23180.711120  23176.637276
# 1      23183.75          0.000588  23182.132754  23181.097130  23177.234343
# 2      23192.95          0.000397  23185.738511  23182.599684  23178.544373
# 3      23199.66          0.000289  23190.379015  23184.758556  23180.293280
# 4      23200.05          0.000017  23193.602680  23186.690607  23181.920035
# ...         ...               ...           ...           ...           ...
# 54055  27928.41          0.000240  27923.489337  27921.943798  27922.157826
# 54056  27928.41          0.000000  27925.129558  27922.752074  27922.638762
# 54057  27933.23          0.000173  27927.829705  27924.061814  27923.453473
# 54058  27923.08         -0.000363  27926.246470  27923.939088  27923.424744
# 54059  27918.12         -0.000178  27923.537647  27923.211702  27923.016687
#
# ...
